# %% [markdown]
# # Final Report | Capstone project - The Batlle of Neighborhoods

# %% [markdown]
# # Introduction

# %% [markdown]
# Toronto is the capital of Ontario and the biggest city in Canada. With its population of 2,731,571 in 2016 it is the most populous in Canada and fourth populous in North America. The deserve population of Toronto makes it the most importatnt destination for immigrants in Canada. While majotiry of poeple speak English, 160 other langagues are spoken there.( this information can be found here) Such a big geographical area, vast population and large number of ethnicities creates a very challenging environment for restaurant businesses. Location is one of key things for the prosperity of the business, therefore it is imortant to choose area, in which cafe and restaurants are the most popular venues and the lowest competition.
#
# Suggest the Traget Audience neighborhoods that are best in terms of location and popularity among people to gain the maximum profit in Toronto, by examining data on most popular venues.

# %% [markdown]
# # Data section

# %% [markdown]
# In this project been used two data sets. First data set consists of Toronto's neignborhoods, boroughs and postalcodes can be found [here](https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M), second data set consist of postalcodes and geopositioning data, which can be downloaded [here](http://cocl.us/Geospatial_data). In order to analyze and build a map of most popular venues in combination with data sets been aslo used Foursquare API. Data retreved from Forsquare API contained information about venues with specific geopositional informationm which is:
# <li> Neighborhood
# <li> Neighborhood latitude and longtitude
# <li>Venue
# <li> Venue latitude and longtitude
# <li> Category of the venue

# %% [markdown]
# # Methodology

# %% [markdown]
# To retrieve information about top venues in all neighborhoods of Toronto, we need to explore and cluster the neighborhoods in Toronto. To explore neighborhoods in the city we use Forsquare API. Foursquare API is a prime data gathering source as it has a database of millions of places, especially their places API which provides the ability to perform location search, location sharing and details about a busines. To cluster we use unsupervised machine learning: k- mean clustering algorithm to custer data. We will form 5 clusters and explore top 10 popular venues in the city of Toronto. We from a dataframe, which would be inserted below.

# %% [markdown]
# To visualize data we build a map, which would be inserted below.

# %% [markdown]
# # Results

# %% [markdown]
# As the result of the work, we formed a dataframe, which consists of postalcode, borough, neighborhood, geopositioning data and 10 most popular vanues. This dataframe is iserted below.

# %% [markdown]
# ![kclustering.PNG](attachment:kclustering.PNG)

# %% [markdown]
# Based on the results, to visualize data the map of clusters was made.

# %% [markdown]
# ![map.PNG](attachment:map.PNG)

# %% [markdown]
# As we can see from the result, food related facilities make up the majority of meering places. Dependng on a neighborhood, sertain type of facility and cuisine is popular. Based on this data, we can make a conclusion, that food related facilities are the most popular venues in Downtown Toronto.

# %% [markdown]
# # Discussion

# %% [markdown]
# The major purpose of this project is to suggest a suitable neighborhood in the city of Toronto for a person who is going to open a food facility (restaurant, cafe, etc.). To reach this purpose several things been done:
# 1. We sorted data, which consited of boroughs, neighborhoods and postalcodes of Toronto. Added geopositioning data to prevoiusly made data frame.
# 2. Using Forsquare API we found top 10 popular venues in Canada and their locations.

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this project we worked with neighborhoods in Toronto. By exploring and sorting data we made a data frame which consisted of different neighborhoods of the city with its boroughs and postalcodes. Using postalcodes data we found a geopositioning data of each neighborhood. Using Forsquare we retreived data on most popular venues and using k-method we formed 5 clusters, which are represented on the map of the city.
#
# To achieve this results, we worked with this libraries
#
# <li> Pandas: Creating and manipulating with dataframes.
#
# <li> Folium: Map rendering library.
#
# <li> Scikit Learn: For k-means clustering.
#
# <li> JSON: Library to handle JSON files.
#
# <li> XML: To separate data from presentation and XML stores data in plain text format.
#
# <li> Geocoder: To retrieve Location Data.
#
# <li> Beautiful Soup and Requests: To handle http requests.
#
# <li> Matplotlib: Python Plotting Module.

# %% [markdown]
# The result we achieved at the end of a Capstone Project can be further used for making more research in terms of popular venues in the city of Toronto. Further developing can make the solution of a problem more complex and more informatively.
